# %% [markdown]
# # Población total, indicadores, índice y grado de rezago social según localidad, 2010

# %% [markdown]
# El Índice de Rezago Social (IRS) permite ordenar las entidades federativas, municipios y localidades de mayor a menor grado de rezago social en un momento del tiempo.

# %% [markdown]
# Es una medida en la que un solo índice agrega variables de educación, de acceso a servicios de salud, de servicios básicos en la vivienda, de calidad y espacios en la misma, y de activos en el hogar. Es decir, proporciona el resumen de cuatro carencias sociales de la medición de pobreza del CONEVAL: rezago educativo, acceso a los servicios de salud, acceso a los servicios básicos en la vivienda y la calidad y espacios en la vivienda.

# %% [markdown]
# No se trata de un medición de pobreza, ya que no incorpora los indicadores de ingreso, seguridad social y alimentación, permite tener información de indicadores sociales desagregados hasta nivel localidad, con lo que CONEVAL contribuye con la generación de datos para la toma de decisiones en materia de política social, especialmente para analizar la desigualdad de coberturas sociales que subsisten en el territorio nacional.

# %% [markdown]
# Estos datos fueron generados por el Consejo Nacional de Evaluación de la Política de Desarrollo Social (CONEVAL), estos son los relacionados con las estimaciones 2010 a nivel estatal, municipal y por localidad con base en el Censo de Población y Vivienda 2010.

# %%
import pandas as pd  ## Import the Pandas package
import numpy as np  ## Import the NumPy package
import folium  #needed for interactive map
from folium.plugins import HeatMap
import os

# %%
Rezago_Social_2010_localidades = os.path.join(os.getcwd(),'data/Rezago_Social_2010_localidades.csv')   ## Load the data into python
rs = pd.read_csv(Rezago_Social_2010_localidades,encoding = "ISO-8859-1")  ### Load a file as a DataFrame and assign to rs

# %%
rs.head()
# Out:
#    Clave localidad Entidad federativa              Municipio  \
# 0         90020001   DISTRITO FEDERAL           AZCAPOTZALCO
# 1         90030001   DISTRITO FEDERAL               COYOACÁN
# 2         90040001   DISTRITO FEDERAL  CUAJIMALPA DE MORELOS
# 3         90040010   DISTRITO FEDERAL  CUAJIMALPA DE MORELOS
# 4         90040020   DISTRITO FEDERAL  CUAJIMALPA DE MORELOS
#
#                Localidad  Población total  \
# 0           AZCAPOTZALCO           414711
# 1               COYOACÁN           620416
# 2  CUAJIMALPA DE MORELOS           160491
# 3            CRUZ BLANCA              581
# 4   SAN LORENZO ACOPILCO            23037
#
#    Población de 15 años o más analfabeta  \
# 0                                 1.6171
# 1                                 1.5366
# 2                                 2.2576
# 3                                 6.3981
# 4                                 2.5760
#
#    Población de 6 a 14 años que no asiste a la escuela  \
# ...

# %%
folium_map = folium.Map(location=[19.4284706, -99.1276627],
                        zoom_start=13,
                        tiles="OpenStreetMap")
#Now we can have a scatter plot of the first 1000 data points on the above map
#for i in range(0,1000):
#    marker = folium.CircleMarker(location=[listings["latitude"][i],listings["longitude"][i]],radius=5,color="r",fill=True)
#    marker.add_to(folium_map)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
